# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
dev_dict = pkl.load(open('data/earthquake/dev.pkl', 'rb'))
test_dict = pkl.load(open('data/earthquake/test.pkl', 'rb'))
train_dict = pkl.load(open('data/earthquake/train.pkl', 'rb'))

# %%
print('dev_dict:', dev_dict)
# Out:
# dev_dict: {'dim_process': 7, 'dev': [[{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 3}, {'time_since_last_event': 0.5486190000083297, 'time_since_start': 0.5486190000083297, 'type_event': 1}, {'time_since_last_event': 0.6663428999891039, 'time_since_start': 1.2149618999974336, 'type_event': 0}, {'time_since_last_event': 2.7089128000079654, 'time_since_start': 3.923874700005399, 'type_event': 3}, {'time_since_last_event': 0.8426292999938596, 'time_since_start': 4.766503999999259, 'type_event': 2}, {'time_since_last_event': 0.018509999994421378, 'time_since_start': 4.78501399999368, 'type_event': 2}, {'time_since_last_event': 0.7265199999965262, 'time_since_start': 5.511533999990206, 'type_event': 0}, {'time_since_last_event': 0.18911279999883845, 'time_since_start': 5.700646799989045, 'type_event': 1}, {'time_since_last_event': 0.05716920000850223, 'time_since_start': 5.757815999997547, 'type_event': 1}, {'time_since_last_event': 0.4891032000014093, 'time_since_start': 6.246919199998956, 'type_event': 0}, {'time_since_last_event': 0.0723848000052385, 'time_since_start': 6.319304000004195, 'type_event': 3}, {'time_since_last_event': 0.1236780000035651, 'time_since_start': 6.44298200000776, 'type_event': 0}, {'time_since_last_event': 0.8130499999970198, 'time_since_start': 7.2560320000047795, 'type_event': 0}, {'time_since_last_event': 0.3471610000124201, 'time_since_start': 7.6031930000172, 'type_event': 0}, {'time_since_last_event': 0.8132219999679364, 'time_since_start': 8.416414999985136, 'type_event': 1}], [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0}, {'time_since_last_event': 1.627037999976892, 'time_since_start': 1.627037999976892, 'type_event': 0}, {'time_since_last_event': 0.5001930000144057, 'time_since_start': 2.1272309999912977, 'type_event': 0}, {'time_since_last_event': 2.9894769999955315, 'time_since_start': 5.116707999986829, 'type_event': 0}, {'time_since_last_event': 2.911263999994844, 'time_since_start': 8.027971999981673, 'type_event': 0}, {'time_since_last_event': 1.2869859999918845, 'time_since_start': 9.314957999973558, 'type_event': 0}, {'time_since_last_event': 0.009126000019023195, 'time_since_start': 9.324083999992581, 'type_event': 0}, {'time_since_last_event': 0.22372599999653175, 'time_since_start': 9.547809999989113, 'type_event': 2}, {'time_since_last_event': 0.2554412999888882, 'time_since_start': 9.803251299978001, 'type_event': 1}, {'time_since_last_event': 5.682026700000279, 'time_since_start': 15.48527799997828, 'type_event': 0}, {'time_since_last_event': 1.3036800000118092, 'time_since_start': 16.78895799999009, 'type_event': 2}, {'time_since_last_event': 0.2506100000173319, 'time_since_start': 17.03956800000742, 'type_event': 0}, {'time_since_last_event': 0.2322099999873899, 'time_since_start': 17.27177799999481, 'type_event': 1}, {'time_since_last_event': 0.474333399994066, 'time_since_start': 17.746111399988877, 'type_event': 0}, {'time_since_last_event': 4.942986000009114, 'time_since_start': 22.68909739999799, 'type_event': 2}, {'time_since_last_event': 1.7973766999784857, 'time_since_start': 24.486474099976476, 'type_event': 1}, {'time_since_last_event': 1.4155815000121947, 'time_since_start': 25.90205559998867, 'type_event': 1}], [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2}, {'time_since_last_event': 0.08252000002539717, 'time_since_start': 0.08252000002539717, 'type_event': 1}, {'time_since_last_event': 0.5620319999870844, 'time_since_start': 0.6445520000124816, 'type_event': 1}, {'time_since_last_event': 0.008319999993545935, 'time_since_start': 0.6528720000060275, 'type_event': 2}, {'time_since_last_event': 0.003851000015856698, 'time_since_start': 0.6567230000218842, 'type_event': 2}, {'time_since_last_event': 3.482773499999894, 'time_since_start': 4.139496500021778, 'type_event': 2}, {'time_since_last_event': 2.58324849998462, 'time_since_start': 6.722745000006398, 'type_event': 1}, {'time_since_last ...

# %%
import random

from easy_tpp.preprocess.event_tokenizer import EventTokenizer
from easy_tpp.config_factory import DataSpecConfig

def make_raw_data():
    data = [
        [{"time_since_last_event": 0, "time_since_start": 0, "type_event": 0}],
        [{"time_since_last_event": 0, "time_since_start": 0, "type_event": 1}],
        [{"time_since_last_event": 0, "time_since_start": 0, "type_event": 1}],
    ]
    for i, j in enumerate([2, 5, 3]):
        start_time = 0
        for k in range(j):
            delta_t = random.random()
            start_time += delta_t
            data[i].append({"time_since_last_event": delta_t,
                            "time_since_start": start_time,
                            "type_event": random.randint(0, 10)
                            })

    return data


def main():
    source_data = make_raw_data()

    time_seqs = [[x["time_since_start"] for x in seq] for seq in source_data]
    type_seqs = [[x["type_event"] for x in seq] for seq in source_data]
    time_delta_seqs = [[x["time_since_last_event"] for x in seq] for seq in source_data]

    input_data = {'time_seqs': time_seqs,
                  'type_seqs': type_seqs,
                  'time_delta_seqs': time_delta_seqs}

    config = DataSpecConfig.parse_from_yaml_config({'num_event_types': 10,  'pad_token_id': 10})

    tokenizer = EventTokenizer(config)

    output = tokenizer.pad(input_data, return_tensors='pt')

    print(output)


if __name__ == '__main__':
    main()
# Out:
# {'time_seqs': tensor([[ 0.0000,  0.3452,  1.1554, 10.0000, 10.0000, 10.0000],
#         [ 0.0000,  0.4125,  1.0235,  1.8393,  2.4094,  2.6727],
#         [ 0.0000,  0.8694,  0.8897,  1.4690, 10.0000, 10.0000]]), 'time_delta_seqs': tensor([[ 0.0000,  0.3452,  0.8102, 10.0000, 10.0000, 10.0000],
#         [ 0.0000,  0.4125,  0.6109,  0.8159,  0.5700,  0.2633],
#         [ 0.0000,  0.8694,  0.0203,  0.5794, 10.0000, 10.0000]]), 'type_seqs': tensor([[ 0,  5,  8, 10, 10, 10],
#         [ 1,  5,  5,  2,  0,  3],
#         [ 1,  1,  4,  1, 10, 10]]), 'seq_non_pad_mask': tensor([[ True,  True,  True, False, False, False],
#         [ True,  True,  True,  True,  True,  True],
#         [ True,  True,  True,  True, False, False]]), 'attention_mask': tensor([[[False,  True,  True,  True,  True,  True],
#          [False, False,  True,  True,  True,  True],
#          [False, False, False,  True,  True,  True],
#          [False, False, False,  True,  True,  True],
#          [False, False, False,  True,  True,  True],
#          [False, False, False,  True,  True,  True]],
#
#         [[False,  True,  True,  True,  True,  True],
#          [False, False,  True,  True,  True,  True],
#          [False, False, False,  True,  True,  True],
#          [False, False, False, False,  True,  True],
#          [False, False, False, False, False,  True],
#          [False, False, False, False, False, False]],
#
#         [[False,  True,  True,  True,  True,  True],
#          [False, False,  True,  True,  True,  True],
#          [False, False, False,  True,  True,  True],
#          [False, False, False, False,  True,  True],
#          [False, False, False, False,  True,  True],
#          [False, False, False, False,  True,  True]]])}

# %%
train_dict
# Out:
# {'dim_process': 7,
#  'train': [[{'time_since_last_event': 0.0,
#     'time_since_start': 0.0,
#     'type_event': 0},
#    {'time_since_last_event': 1.2051030000002356,
#     'time_since_start': 1.2051030000002356,
#     'type_event': 0},
#    {'time_since_last_event': 0.033874000000650994,
#     'time_since_start': 1.2389770000008866,
#     'type_event': 1},
#    {'time_since_last_event': 0.33377300000574905,
#     'time_since_start': 1.5727500000066357,
#     'type_event': 2},
#    {'time_since_last_event': 0.10636799999338109,
#     'time_since_start': 1.6791180000000168,
#     'type_event': 0},
#    {'time_since_last_event': 0.4333000000042375,
#     'time_since_start': 2.1124180000042543,
#     'type_event': 0},
#    {'time_since_last_event': 1.4924579999933485,
#     'time_since_start': 3.6048759999976028,
#     'type_event': 2},
#    {'time_since_last_event': 0.2127420000033453,
#     'time_since_start': 3.817618000000948,
#     'type_event': 0},
#    {'time_since_last_event': 0.017842999994172715,
#     'time_since_start': 3.835460999995121,
#     'type_event': 2},
#    {'time_since_last_event': 1.4734890000108862,
#     'time_since_start': 5.308950000006007,
#     'type_event': 0},
#    {'time_since_last_event': 0.8189029999921331,
#     'time_since_start': 6.12785299999814,
#     'type_event': 0},
#    {'time_since_last_event': 7.919684000007692,
#     'time_since_start': 14.047537000005832,
#     'type_event': 0},
#    {'time_since_last_event': 0.497600999995484,
#     'time_since_start': 14.545138000001316,
#     'type_event': 0},
#    {'time_since_last_event': 4.747799000004306,
#     'time_since_start': 19.292937000005622,
#     'type_event': 1},
#    {'time_since_last_event': 0.20941199999651872,
#     'time_since_start': 19.50234900000214,
#     'type_event': 0},
#    {'time_since_last_event': 0.31534499999543186,
#     'time_since_start': 19.817693999997573,
#     'type_event': 0},
#    {'time_since_last_event': 0.024082000003545545,
#     'time_since_start': 19.84177600000112,
#     'type_event': 6}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 5.620814000008977,
#     'time_since_start': 5.620814000008977,
#     'type_event': 0},
#    {'time_since_last_event': 0.12561499999719672,
#     'time_since_start': 5.746429000006174,
#     'type_event': 3},
#    {'time_since_last_event': 0.5546920000051614,
#     'time_since_start': 6.301121000011335,
#     'type_event': 2},
#    {'time_since_last_event': 0.1963159999868367,
#     'time_since_start': 6.497436999998172,
#     'type_event': 0},
#    {'time_since_last_event': 2.8633370000025025,
#     'time_since_start': 9.360774000000674,
#     'type_event': 0},
#    {'time_since_last_event': 1.355068000004394,
#     'time_since_start': 10.715842000005068,
#     'type_event': 2},
#    {'time_since_last_event': 2.0346640000061598,
#     'time_since_start': 12.750506000011228,
#     'type_event': 0},
#    {'time_since_last_event': 1.3743990000075428,
#     'time_since_start': 14.12490500001877,
#     'type_event': 3},
#    {'time_since_last_event': 0.0233379999990575,
#     'time_since_start': 14.148243000017828,
#     'type_event': 2},
#    {'time_since_last_event': 2.900746999977855,
#     'time_since_start': 17.048989999995683,
#     'type_event': 2},
#    {'time_since_last_event': 0.05111000001488719,
#     'time_since_start': 17.10010000001057,
#     'type_event': 0},
#    {'time_since_last_event': 0.0076730000000679865,
#     'time_since_start': 17.10777300001064,
#     'type_event': 0},
#    {'time_since_last_event': 0.6524490000010701,
#     'time_since_start': 17.76022200001171,
#     'type_event': 0},
#    {'time_since_last_event': 3.6643439999897964,
#     'time_since_start': 21.424566000001505,
#     'type_event': 0},
#    {'time_since_last_event': 0.6480739999969956,
#     'time_since_start': 22.0726399999985,
#     'type_event': 0},
#    {'time_since_last_event': 1.8403260000050068,
#     'time_since_start': 23.912966000003507,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 0.13861999998334795,
#     'time_since_start': 0.13861999998334795,
#     'type_event': 1},
#    {'time_since_last_event': 9.545355000009295,
#     'time_since_start': 9.683974999992643,
#     'type_event': 3},
#    {'time_since_last_event': 4.718003000001772,
#     'time_since_start': 14.401977999994415,
#     'type_event': 0},
#    {'time_since_last_event': 0.7897419999935664,
#     'time_since_start': 15.191719999987981,
#     'type_event': 1},
#    {'time_since_last_event': 2.899548000001232,
#     'time_since_start': 18.091267999989213,
#     'type_event': 2},
#    {'time_since_last_event': 4.4198810000089,
#     'time_since_start': 22.511148999998113,
#     'type_event': 0},
#    {'time_since_last_event': 7.307768999991822,
#     'time_since_start': 29.818917999989935,
#     'type_event': 1},
#    {'time_since_last_event': 1.4930779999995138,
#     'time_since_start': 31.31199599998945,
#     'type_event': 0},
#    {'time_since_last_event': 4.689454000006663,
#     'time_since_start': 36.00144999999611,
#     'type_event': 3},
#    {'time_since_last_event': 0.9981560000014724,
#     'time_since_start': 36.999605999997584,
#     'type_event': 0},
#    {'time_since_last_event': 6.183619000003091,
#     'time_since_start': 43.183225000000675,
#     'type_event': 1},
#    {'time_since_last_event': 4.859983999980614,
#     'time_since_start': 48.04320899998129,
#     'type_event': 1},
#    {'time_since_last_event': 0.4965350000129547,
#     'time_since_start': 48.53974399999424,
#     'type_event': 2},
#    {'time_since_last_event': 2.0110139999887906,
#     'time_since_start': 50.550757999983034,
#     'type_event': 1},
#    {'time_since_last_event': 1.6073160000087228,
#     'time_since_start': 52.15807399999176,
#     'type_event': 3},
#    {'time_since_last_event': 0.0054099999979371205,
#     'time_since_start': 52.163483999989694,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.6350960000127088,
#     'time_since_start': 0.6350960000127088,
#     'type_event': 1},
#    {'time_since_last_event': 1.3240359999908833,
#     'time_since_start': 1.9591320000035921,
#     'type_event': 0},
#    {'time_since_last_event': 2.7096000000019558,
#     'time_since_start': 4.668732000005548,
#     'type_event': 1},
#    {'time_since_last_event': 4.629669999994803,
#     'time_since_start': 9.298402000000351,
#     'type_event': 2},
#    {'time_since_last_event': 1.3053580000123475,
#     'time_since_start': 10.603760000012699,
#     'type_event': 2},
#    {'time_since_last_event': 0.3917679999867687,
#     'time_since_start': 10.995527999999467,
#     'type_event': 2},
#    {'time_since_last_event': 1.260167000014917,
#     'time_since_start': 12.255695000014384,
#     'type_event': 2},
#    {'time_since_last_event': 8.11593199998606,
#     'time_since_start': 20.371627000000444,
#     'type_event': 0},
#    {'time_since_last_event': 0.47465899999951944,
#     'time_since_start': 20.846285999999964,
#     'type_event': 0},
#    {'time_since_last_event': 2.4987120000005234,
#     'time_since_start': 23.344998000000487,
#     'type_event': 0},
#    {'time_since_last_event': 1.6450370000093244,
#     'time_since_start': 24.99003500000981,
#     'type_event': 0},
#    {'time_since_last_event': 1.9831429999903776,
#     'time_since_start': 26.97317800000019,
#     'type_event': 0},
#    {'time_since_last_event': 2.6154810000007274,
#     'time_since_start': 29.588659000000916,
#     'type_event': 0},
#    {'time_since_last_event': 0.2126890000072308,
#     'time_since_start': 29.801348000008147,
#     'type_event': 0},
#    {'time_since_last_event': 12.059745000005933,
#     'time_since_start': 41.86109300001408,
#     'type_event': 0},
#    {'time_since_last_event': 0.460438999987673,
#     'time_since_start': 42.32153200000175,
#     'type_event': 1}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 3.554595000008703,
#     'time_since_start': 3.554595000008703,
#     'type_event': 0},
#    {'time_since_last_event': 4.54407099999662,
#     'time_since_start': 8.098666000005323,
#     'type_event': 0},
#    {'time_since_last_event': 0.4059469999920111,
#     'time_since_start': 8.504612999997335,
#     'type_event': 2},
#    {'time_since_last_event': 1.016449000002467,
#     'time_since_start': 9.521061999999802,
#     'type_event': 0},
#    {'time_since_last_event': 7.714529999997467,
#     'time_since_start': 17.23559199999727,
#     'type_event': 0},
#    {'time_since_last_event': 10.022984000010183,
#     'time_since_start': 27.25857600000745,
#     'type_event': 1},
#    {'time_since_last_event': 5.018505000000005,
#     'time_since_start': 32.277081000007456,
#     'type_event': 0},
#    {'time_since_last_event': 2.3167990000074496,
#     'time_since_start': 34.593880000014906,
#     'type_event': 1},
#    {'time_since_last_event': 2.3698309999890625,
#     'time_since_start': 36.96371100000397,
#     'type_event': 1},
#    {'time_since_last_event': 5.198755000004894,
#     'time_since_start': 42.16246600000886,
#     'type_event': 3},
#    {'time_since_last_event': 2.898603000008734,
#     'time_since_start': 45.061069000017596,
#     'type_event': 3},
#    {'time_since_last_event': 10.919410999995307,
#     'time_since_start': 55.9804800000129,
#     'type_event': 0},
#    {'time_since_last_event': 0.00922899998840876,
#     'time_since_start': 55.98970900000131,
#     'type_event': 2},
#    {'time_since_last_event': 0.16697200000635348,
#     'time_since_start': 56.156681000007666,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.01324100000783801,
#     'time_since_start': 0.01324100000783801,
#     'type_event': 0},
#    {'time_since_last_event': 9.644729000006919,
#     'time_since_start': 9.657970000014757,
#     'type_event': 1},
#    {'time_since_last_event': 6.880753999997978,
#     'time_since_start': 16.538724000012735,
#     'type_event': 0},
#    {'time_since_last_event': 1.60538799999631,
#     'time_since_start': 18.144112000009045,
#     'type_event': 2},
#    {'time_since_last_event': 0.015335999996750616,
#     'time_since_start': 18.159448000005796,
#     'type_event': 1},
#    {'time_since_last_event': 7.404238000002806,
#     'time_since_start': 25.5636860000086,
#     'type_event': 2},
#    {'time_since_last_event': 0.29855600000882987,
#     'time_since_start': 25.86224200001743,
#     'type_event': 1},
#    {'time_since_last_event': 5.605976999999257,
#     'time_since_start': 31.46821900001669,
#     'type_event': 1},
#    {'time_since_last_event': 0.691553999989992,
#     'time_since_start': 32.15977300000668,
#     'type_event': 2},
#    {'time_since_last_event': 3.317196000003605,
#     'time_since_start': 35.476969000010286,
#     'type_event': 3},
#    {'time_since_last_event': 3.6466119999968214,
#     'time_since_start': 39.12358100000711,
#     'type_event': 1},
#    {'time_since_last_event': 0.07509600000048522,
#     'time_since_start': 39.19867700000759,
#     'type_event': 0},
#    {'time_since_last_event': 5.055080999998609,
#     'time_since_start': 44.2537580000062,
#     'type_event': 0},
#    {'time_since_last_event': 4.431513999996241,
#     'time_since_start': 48.68527200000244,
#     'type_event': 0},
#    {'time_since_last_event': 2.644000000000233,
#     'time_since_start': 51.329272000002675,
#     'type_event': 6},
#    {'time_since_last_event': 0.4300700000167126,
#     'time_since_start': 51.75934200001939,
#     'type_event': 4},
#    {'time_since_last_event': 2.983710999978939,
#     'time_since_start': 54.743052999998326,
#     'type_event': 1}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 1},
#    {'time_since_last_event': 1.650828999991063,
#     'time_since_start': 1.650828999991063,
#     'type_event': 0},
#    {'time_since_last_event': 2.2054369999968912,
#     'time_since_start': 3.8562659999879543,
#     'type_event': 1},
#    {'time_since_last_event': 2.380209000009927,
#     'time_since_start': 6.236474999997881,
#     'type_event': 0},
#    {'time_since_last_event': 16.66372599999886,
#     'time_since_start': 22.90020099999674,
#     'type_event': 2},
#    {'time_since_last_event': 0.7712009999959264,
#     'time_since_start': 23.671401999992668,
#     'type_event': 1},
#    {'time_since_last_event': 0.8620200000004843,
#     'time_since_start': 24.533421999993152,
#     'type_event': 0},
#    {'time_since_last_event': 0.999749000009615,
#     'time_since_start': 25.533171000002767,
#     'type_event': 1},
#    {'time_since_last_event': 3.287637999994331,
#     'time_since_start': 28.820808999997098,
#     'type_event': 1},
#    {'time_since_last_event': 0.0031750000052852556,
#     'time_since_start': 28.823984000002383,
#     'type_event': 0},
#    {'time_since_last_event': 0.04314999999769498,
#     'time_since_start': 28.86713400000008,
#     'type_event': 1},
#    {'time_since_last_event': 1.1620319999929052,
#     'time_since_start': 30.029165999992983,
#     'type_event': 2},
#    {'time_since_last_event': 9.226615999999922,
#     'time_since_start': 39.255781999992905,
#     'type_event': 0},
#    {'time_since_last_event': 0.44225700000242796,
#     'time_since_start': 39.69803899999533,
#     'type_event': 3},
#    {'time_since_last_event': 0.4631050000025425,
#     'time_since_start': 40.161143999997876,
#     'type_event': 0},
#    {'time_since_last_event': 0.010448000000906177,
#     'time_since_start': 40.17159199999878,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 1},
#    {'time_since_last_event': 2.5154360000015004,
#     'time_since_start': 2.5154360000015004,
#     'type_event': 4},
#    {'time_since_last_event': 0.61048699998355,
#     'time_since_start': 3.1259229999850504,
#     'type_event': 1},
#    {'time_since_last_event': 0.37521800001559313,
#     'time_since_start': 3.5011410000006435,
#     'type_event': 1},
#    {'time_since_last_event': 1.1715709999989485,
#     'time_since_start': 4.672711999999592,
#     'type_event': 1},
#    {'time_since_last_event': 0.11529899999732152,
#     'time_since_start': 4.788010999996914,
#     'type_event': 0},
#    {'time_since_last_event': 0.8729940000048373,
#     'time_since_start': 5.661005000001751,
#     'type_event': 0},
#    {'time_since_last_event': 5.39205999999831,
#     'time_since_start': 11.05306500000006,
#     'type_event': 0},
#    {'time_since_last_event': 1.6721340000076452,
#     'time_since_start': 12.725199000007706,
#     'type_event': 1},
#    {'time_since_last_event': 4.882481999986339,
#     'time_since_start': 17.607680999994045,
#     'type_event': 2},
#    {'time_since_last_event': 3.4375029999937396,
#     'time_since_start': 21.045183999987785,
#     'type_event': 0},
#    {'time_since_last_event': 7.295266000015545,
#     'time_since_start': 28.34045000000333,
#     'type_event': 1},
#    {'time_since_last_event': 1.443805999995675,
#     'time_since_start': 29.784255999999004,
#     'type_event': 0},
#    {'time_since_last_event': 2.97255099999893,
#     'time_since_start': 32.756806999997934,
#     'type_event': 1},
#    {'time_since_last_event': 0.8625869999959832,
#     'time_since_start': 33.61939399999392,
#     'type_event': 3},
#    {'time_since_last_event': 0.00935199999366887,
#     'time_since_start': 33.628745999987586,
#     'type_event': 2},
#    {'time_since_last_event': 0.027878000008058734,
#     'time_since_start': 33.656623999995645,
#     'type_event': 0},
#    {'time_since_last_event': 0.3023969999921974,
#     'time_since_start': 33.95902099998784,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 1},
#    {'time_since_last_event': 0.5863859999808483,
#     'time_since_start': 0.5863859999808483,
#     'type_event': 2},
#    {'time_since_last_event': 3.468112000002293,
#     'time_since_start': 4.054497999983141,
#     'type_event': 2},
#    {'time_since_last_event': 0.1157999999995809,
#     'time_since_start': 4.170297999982722,
#     'type_event': 0},
#    {'time_since_last_event': 4.482259000011254,
#     'time_since_start': 8.652556999993976,
#     'type_event': 0},
#    {'time_since_last_event': 4.088277999995626,
#     'time_since_start': 12.740834999989602,
#     'type_event': 0},
#    {'time_since_last_event': 0.7019060000020545,
#     'time_since_start': 13.442740999991656,
#     'type_event': 0},
#    {'time_since_last_event': 3.0623239999986254,
#     'time_since_start': 16.50506499999028,
#     'type_event': 1},
#    {'time_since_last_event': 2.7710430000006454,
#     'time_since_start': 19.276107999990927,
#     'type_event': 1},
#    {'time_since_last_event': 4.044636000005994,
#     'time_since_start': 23.32074399999692,
#     'type_event': 1},
#    {'time_since_last_event': 3.7951979999925243,
#     'time_since_start': 27.115941999989445,
#     'type_event': 0},
#    {'time_since_last_event': 1.2648559999943245,
#     'time_since_start': 28.38079799998377,
#     'type_event': 1},
#    {'time_since_last_event': 6.41397200000938,
#     'time_since_start': 34.79476999999315,
#     'type_event': 1},
#    {'time_since_last_event': 4.100619999997434,
#     'time_since_start': 38.895389999990584,
#     'type_event': 0},
#    {'time_since_last_event': 1.0597470000066096,
#     'time_since_start': 39.955136999997194,
#     'type_event': 1}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 1.6883519999973942,
#     'time_since_start': 1.6883519999973942,
#     'type_event': 4},
#    {'time_since_last_event': 2.8025349999952596,
#     'time_since_start': 4.490886999992654,
#     'type_event': 3},
#    {'time_since_last_event': 0.2512730000016745,
#     'time_since_start': 4.742159999994328,
#     'type_event': 0},
#    {'time_since_last_event': 1.1693470000027446,
#     'time_since_start': 5.911506999997073,
#     'type_event': 3},
#    {'time_since_last_event': 1.0204389999998966,
#     'time_since_start': 6.9319459999969695,
#     'type_event': 1},
#    {'time_since_last_event': 7.782679999989341,
#     'time_since_start': 14.71462599998631,
#     'type_event': 2},
#    {'time_since_last_event': 0.5608350000111386,
#     'time_since_start': 15.275460999997449,
#     'type_event': 1},
#    {'time_since_last_event': 0.003754999997909181,
#     'time_since_start': 15.279215999995358,
#     'type_event': 1},
#    {'time_since_last_event': 0.22620799999276642,
#     'time_since_start': 15.505423999988125,
#     'type_event': 1},
#    {'time_since_last_event': 0.17836900001566391,
#     'time_since_start': 15.683793000003789,
#     'type_event': 1},
#    {'time_since_last_event': 0.013076999995973893,
#     'time_since_start': 15.696869999999763,
#     'type_event': 1},
#    {'time_since_last_event': 3.28401699999813,
#     'time_since_start': 18.980886999997892,
#     'type_event': 1},
#    {'time_since_last_event': 1.5277029999997467,
#     'time_since_start': 20.50858999999764,
#     'type_event': 3},
#    {'time_since_last_event': 0.4242809999996098,
#     'time_since_start': 20.93287099999725,
#     'type_event': 4},
#    {'time_since_last_event': 2.8292510000028415,
#     'time_since_start': 23.76212200000009,
#     'type_event': 3},
#    {'time_since_last_event': 1.068290999988676,
#     'time_since_start': 24.830412999988766,
#     'type_event': 4},
#    {'time_since_last_event': 7.008390999995754,
#     'time_since_start': 31.83880399998452,
#     'type_event': 1}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 1.045122999988962,
#     'time_since_start': 1.045122999988962,
#     'type_event': 0},
#    {'time_since_last_event': 2.006451000008383,
#     'time_since_start': 3.051573999997345,
#     'type_event': 3},
#    {'time_since_last_event': 1.3113369999919087,
#     'time_since_start': 4.3629109999892535,
#     'type_event': 0},
#    {'time_since_last_event': 0.7038120000070194,
#     'time_since_start': 5.066722999996273,
#     'type_event': 0},
#    {'time_since_last_event': 3.1651359999959823,
#     'time_since_start': 8.231858999992255,
#     'type_event': 3},
#    {'time_since_last_event': 2.1654299999936484,
#     'time_since_start': 10.397288999985904,
#     'type_event': 0},
#    {'time_since_last_event': 0.05400200000440236,
#     'time_since_start': 10.451290999990306,
#     'type_event': 0},
#    {'time_since_last_event': 0.5822239999979502,
#     'time_since_start': 11.033514999988256,
#     'type_event': 1},
#    {'time_since_last_event': 6.8112680000049295,
#     'time_since_start': 17.844782999993186,
#     'type_event': 1},
#    {'time_since_last_event': 2.06392099999357,
#     'time_since_start': 19.908703999986756,
#     'type_event': 1},
#    {'time_since_last_event': 3.4098570000060135,
#     'time_since_start': 23.31856099999277,
#     'type_event': 4},
#    {'time_since_last_event': 0.10689999999885913,
#     'time_since_start': 23.42546099999163,
#     'type_event': 1},
#    {'time_since_last_event': 0.30613300000550225,
#     'time_since_start': 23.73159399999713,
#     'type_event': 3},
#    {'time_since_last_event': 7.703852000006009,
#     'time_since_start': 31.43544600000314,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 1.5714569999981904,
#     'time_since_start': 1.5714569999981904,
#     'type_event': 3},
#    {'time_since_last_event': 2.178636999989976,
#     'time_since_start': 3.7500939999881666,
#     'type_event': 2},
#    {'time_since_last_event': 1.9243420000129845,
#     'time_since_start': 5.674436000001151,
#     'type_event': 0},
#    {'time_since_last_event': 0.48376499999722,
#     'time_since_start': 6.158200999998371,
#     'type_event': 2},
#    {'time_since_last_event': 1.1221890000015264,
#     'time_since_start': 7.2803899999998976,
#     'type_event': 0},
#    {'time_since_last_event': 8.685522999992827,
#     'time_since_start': 15.965912999992725,
#     'type_event': 1},
#    {'time_since_last_event': 3.635804999998072,
#     'time_since_start': 19.601717999990797,
#     'type_event': 0},
#    {'time_since_last_event': 8.317052000013064,
#     'time_since_start': 27.91877000000386,
#     'type_event': 0},
#    {'time_since_last_event': 12.06743599998299,
#     'time_since_start': 39.98620599998685,
#     'type_event': 1},
#    {'time_since_last_event': 0.5507510000024922,
#     'time_since_start': 40.53695699998934,
#     'type_event': 0},
#    {'time_since_last_event': 11.218613000019104,
#     'time_since_start': 51.75557000000845,
#     'type_event': 0},
#    {'time_since_last_event': 9.34214099998644,
#     'time_since_start': 61.09771099999489,
#     'type_event': 2},
#    {'time_since_last_event': 5.3306180000072345,
#     'time_since_start': 66.42832900000212,
#     'type_event': 2},
#    {'time_since_last_event': 0.6024319999996806,
#     'time_since_start': 67.0307610000018,
#     'type_event': 2},
#    {'time_since_last_event': 2.6790469999978086,
#     'time_since_start': 69.70980799999961,
#     'type_event': 2},
#    {'time_since_last_event': 3.8681150000047637,
#     'time_since_start': 73.57792300000438,
#     'type_event': 0},
#    {'time_since_last_event': 0.5934629999974277,
#     'time_since_start': 74.1713860000018,
#     'type_event': 2}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.09524200001033023,
#     'time_since_start': 0.09524200001033023,
#     'type_event': 0},
#    {'time_since_last_event': 3.591781999988598,
#     'time_since_start': 3.687023999998928,
#     'type_event': 2},
#    {'time_since_last_event': 0.35872699999890756,
#     'time_since_start': 4.045750999997836,
#     'type_event': 2},
#    {'time_since_last_event': 7.089409000007436,
#     'time_since_start': 11.135160000005271,
#     'type_event': 2},
#    {'time_since_last_event': 3.0655580000020564,
#     'time_since_start': 14.200718000007328,
#     'type_event': 1},
#    {'time_since_last_event': 10.234904999990249,
#     'time_since_start': 24.435622999997577,
#     'type_event': 0},
#    {'time_since_last_event': 0.040508000005502254,
#     'time_since_start': 24.47613100000308,
#     'type_event': 2},
#    {'time_since_last_event': 0.9089319999911822,
#     'time_since_start': 25.38506299999426,
#     'type_event': 0},
#    {'time_since_last_event': 0.7180400000070222,
#     'time_since_start': 26.103103000001283,
#     'type_event': 0},
#    {'time_since_last_event': 2.6742140000133077,
#     'time_since_start': 28.77731700001459,
#     'type_event': 0},
#    {'time_since_last_event': 5.260779999996885,
#     'time_since_start': 34.038097000011476,
#     'type_event': 0},
#    {'time_since_last_event': 5.3955259999929694,
#     'time_since_start': 39.433623000004445,
#     'type_event': 3},
#    {'time_since_last_event': 0.5543080000061309,
#     'time_since_start': 39.987931000010576,
#     'type_event': 0},
#    {'time_since_last_event': 12.091736999995192,
#     'time_since_start': 52.07966800000577,
#     'type_event': 0},
#    {'time_since_last_event': 7.926428999999189,
#     'time_since_start': 60.00609700000496,
#     'type_event': 0},
#    {'time_since_last_event': 4.265125000005355,
#     'time_since_start': 64.27122200001031,
#     'type_event': 0},
#    {'time_since_last_event': 4.8482659999863245,
#     'time_since_start': 69.11948799999664,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 2.2610119999881135,
#     'time_since_start': 2.2610119999881135,
#     'type_event': 0},
#    {'time_since_last_event': 8.775569000004907,
#     'time_since_start': 11.03658099999302,
#     'type_event': 0},
#    {'time_since_last_event': 0.6350890000030631,
#     'time_since_start': 11.671669999996084,
#     'type_event': 0},
#    {'time_since_last_event': 0.07119799999054521,
#     'time_since_start': 11.742867999986629,
#     'type_event': 2},
#    {'time_since_last_event': 4.114168000000063,
#     'time_since_start': 15.857035999986692,
#     'type_event': 0},
#    {'time_since_last_event': 5.616882000002079,
#     'time_since_start': 21.47391799998877,
#     'type_event': 0},
#    {'time_since_last_event': 2.0034040000027744,
#     'time_since_start': 23.477321999991545,
#     'type_event': 3},
#    {'time_since_last_event': 0.6833629999891855,
#     'time_since_start': 24.16068499998073,
#     'type_event': 1},
#    {'time_since_last_event': 0.4497630000114441,
#     'time_since_start': 24.610447999992175,
#     'type_event': 0},
#    {'time_since_last_event': 4.776708999997936,
#     'time_since_start': 29.38715699999011,
#     'type_event': 2},
#    {'time_since_last_event': 5.555351999995764,
#     'time_since_start': 34.942508999985876,
#     'type_event': 3},
#    {'time_since_last_event': 0.10392799999681301,
#     'time_since_start': 35.04643699998269,
#     'type_event': 0},
#    {'time_since_last_event': 2.355816000010236,
#     'time_since_start': 37.402252999992925,
#     'type_event': 1},
#    {'time_since_last_event': 2.9000579999992624,
#     'time_since_start': 40.30231099999219,
#     'type_event': 1},
#    {'time_since_last_event': 5.234580999996979,
#     'time_since_start': 45.536891999989166,
#     'type_event': 2},
#    {'time_since_last_event': 2.0468710000131978,
#     'time_since_start': 47.583763000002364,
#     'type_event': 1}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 3.7721509999973932,
#     'time_since_start': 3.7721509999973932,
#     'type_event': 2},
#    {'time_since_last_event': 1.3362280000001192,
#     'time_since_start': 5.108378999997512,
#     'type_event': 0},
#    {'time_since_last_event': 0.025725999992573634,
#     'time_since_start': 5.134104999990086,
#     'type_event': 2},
#    {'time_since_last_event': 2.281544000012218,
#     'time_since_start': 7.415649000002304,
#     'type_event': 1},
#    {'time_since_last_event': 5.863769999996293,
#     'time_since_start': 13.279418999998597,
#     'type_event': 2},
#    {'time_since_last_event': 1.1176669999986188,
#     'time_since_start': 14.397085999997216,
#     'type_event': 0},
#    {'time_since_last_event': 0.23762699999497272,
#     'time_since_start': 14.634712999992189,
#     'type_event': 2},
#    {'time_since_last_event': 1.0249090000143042,
#     'time_since_start': 15.659622000006493,
#     'type_event': 3},
#    {'time_since_last_event': 2.3172359999880427,
#     'time_since_start': 17.976857999994536,
#     'type_event': 0},
#    {'time_since_last_event': 0.5827640000061365,
#     'time_since_start': 18.559622000000672,
#     'type_event': 0},
#    {'time_since_last_event': 3.583742999995593,
#     'time_since_start': 22.143364999996265,
#     'type_event': 1},
#    {'time_since_last_event': 2.054073999999673,
#     'time_since_start': 24.19743899999594,
#     'type_event': 0},
#    {'time_since_last_event': 0.7818560000014259,
#     'time_since_start': 24.979294999997364,
#     'type_event': 2},
#    {'time_since_last_event': 10.281727000008686,
#     'time_since_start': 35.26102200000605,
#     'type_event': 2},
#    {'time_since_last_event': 1.1039049999963026,
#     'time_since_start': 36.36492700000235,
#     'type_event': 2},
#    {'time_since_last_event': 0.06986099999630824,
#     'time_since_start': 36.43478799999866,
#     'type_event': 1},
#    {'time_since_last_event': 4.638084999998682,
#     'time_since_start': 41.072872999997344,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 1},
#    {'time_since_last_event': 0.44977300000027753,
#     'time_since_start': 0.44977300000027753,
#     'type_event': 0},
#    {'time_since_last_event': 0.7046649999974761,
#     'time_since_start': 1.1544379999977536,
#     'type_event': 1},
#    {'time_since_last_event': 8.437109999998938,
#     'time_since_start': 9.591547999996692,
#     'type_event': 0},
#    {'time_since_last_event': 2.351488000000245,
#     'time_since_start': 11.943035999996937,
#     'type_event': 1},
#    {'time_since_last_event': 4.577986000003875,
#     'time_since_start': 16.521022000000812,
#     'type_event': 2},
#    {'time_since_last_event': 8.757861999998568,
#     'time_since_start': 25.27888399999938,
#     'type_event': 0},
#    {'time_since_last_event': 0.08120200000121258,
#     'time_since_start': 25.360086000000592,
#     'type_event': 0},
#    {'time_since_last_event': 4.790821999995387,
#     'time_since_start': 30.15090799999598,
#     'type_event': 3},
#    {'time_since_last_event': 1.1882490000134567,
#     'time_since_start': 31.339157000009436,
#     'type_event': 0},
#    {'time_since_last_event': 0.23485199999413453,
#     'time_since_start': 31.57400900000357,
#     'type_event': 2},
#    {'time_since_last_event': 3.38068299999577,
#     'time_since_start': 34.95469199999934,
#     'type_event': 1},
#    {'time_since_last_event': 5.495040000008885,
#     'time_since_start': 40.449732000008225,
#     'type_event': 0},
#    {'time_since_last_event': 1.1054730000032578,
#     'time_since_start': 41.55520500001148,
#     'type_event': 1},
#    {'time_since_last_event': 0.33850599998550024,
#     'time_since_start': 41.89371099999698,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 0.10885499999858439,
#     'time_since_start': 0.10885499999858439,
#     'type_event': 1},
#    {'time_since_last_event': 4.758329000003869,
#     'time_since_start': 4.867184000002453,
#     'type_event': 4},
#    {'time_since_last_event': 0.00907399998686742,
#     'time_since_start': 4.8762579999893205,
#     'type_event': 1},
#    {'time_since_last_event': 0.1918290000030538,
#     'time_since_start': 5.068086999992374,
#     'type_event': 2},
#    {'time_since_last_event': 3.189323000013246,
#     'time_since_start': 8.25741000000562,
#     'type_event': 1},
#    {'time_since_last_event': 3.297802999994019,
#     'time_since_start': 11.55521299999964,
#     'type_event': 6},
#    {'time_since_last_event': 0.018450000003213063,
#     'time_since_start': 11.573663000002853,
#     'type_event': 0},
#    {'time_since_last_event': 0.030549000002793036,
#     'time_since_start': 11.604212000005646,
#     'type_event': 1},
#    {'time_since_last_event': 0.032892999981413595,
#     'time_since_start': 11.63710499998706,
#     'type_event': 2},
#    {'time_since_last_event': 0.051780000008875504,
#     'time_since_start': 11.688884999995935,
#     'type_event': 0},
#    {'time_since_last_event': 0.040609999996377155,
#     'time_since_start': 11.729494999992312,
#     'type_event': 0},
#    {'time_since_last_event': 0.0018720000080065802,
#     'time_since_start': 11.731367000000319,
#     'type_event': 1},
#    {'time_since_last_event': 0.1105189999943832,
#     'time_since_start': 11.841885999994702,
#     'type_event': 2},
#    {'time_since_last_event': 0.1681350000144448,
#     'time_since_start': 12.010021000009147,
#     'type_event': 3},
#    {'time_since_last_event': 0.1451659999875119,
#     'time_since_start': 12.155186999996658,
#     'type_event': 1},
#    {'time_since_last_event': 0.003372999999555759,
#     'time_since_start': 12.158559999996214,
#     'type_event': 2},
#    {'time_since_last_event': 0.03946899999573361,
#     'time_since_start': 12.198028999991948,
#     'type_event': 1}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 3},
#    {'time_since_last_event': 0.0076920000137761235,
#     'time_since_start': 0.0076920000137761235,
#     'type_event': 1},
#    {'time_since_last_event': 0.006660999977611937,
#     'time_since_start': 0.01435299999138806,
#     'type_event': 0},
#    {'time_since_last_event': 0.10137400000530761,
#     'time_since_start': 0.11572699999669567,
#     'type_event': 0},
#    {'time_since_last_event': 0.31629800000519026,
#     'time_since_start': 0.43202500000188593,
#     'type_event': 2},
#    {'time_since_last_event': 0.3552729999937583,
#     'time_since_start': 0.7872979999956442,
#     'type_event': 1},
#    {'time_since_last_event': 0.029351000004680827,
#     'time_since_start': 0.816649000000325,
#     'type_event': 1},
#    {'time_since_last_event': 0.002426000006380491,
#     'time_since_start': 0.8190750000067055,
#     'type_event': 0},
#    {'time_since_last_event': 0.047642999998060986,
#     'time_since_start': 0.8667180000047665,
#     'type_event': 0},
#    {'time_since_last_event': 0.01660799999081064,
#     'time_since_start': 0.8833259999955771,
#     'type_event': 0},
#    {'time_since_last_event': 0.03235500001756009,
#     'time_since_start': 0.9156810000131372,
#     'type_event': 0},
#    {'time_since_last_event': 1.3844029999891063,
#     'time_since_start': 2.3000840000022436,
#     'type_event': 1},
#    {'time_since_last_event': 1.011796000006143,
#     'time_since_start': 3.3118800000083866,
#     'type_event': 0},
#    {'time_since_last_event': 0.40957600000547245,
#     'time_since_start': 3.721456000013859,
#     'type_event': 3},
#    {'time_since_last_event': 0.00456399998802226,
#     'time_since_start': 3.7260200000018813,
#     'type_event': 1},
#    {'time_since_last_event': 0.05018700000073295,
#     'time_since_start': 3.7762070000026142,
#     'type_event': 0},
#    {'time_since_last_event': 0.42191900000034366,
#     'time_since_start': 4.198126000002958,
#     'type_event': 1},
#    {'time_since_last_event': 0.48423999999067746,
#     'time_since_start': 4.682365999993635,
#     'type_event': 2}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 1.0917940000072122,
#     'time_since_start': 1.0917940000072122,
#     'type_event': 0},
#    {'time_since_last_event': 1.9477249999908963,
#     'time_since_start': 3.0395189999981085,
#     'type_event': 1},
#    {'time_since_last_event': 0.0640620000049239,
#     'time_since_start': 3.1035810000030324,
#     'type_event': 0},
#    {'time_since_last_event': 0.27065700000093784,
#     'time_since_start': 3.3742380000039702,
#     'type_event': 0},
#    {'time_since_last_event': 0.09628899999370333,
#     'time_since_start': 3.4705269999976736,
#     'type_event': 1},
#    {'time_since_last_event': 0.14828500000294298,
#     'time_since_start': 3.6188120000006165,
#     'type_event': 2},
#    {'time_since_last_event': 0.013537999999243766,
#     'time_since_start': 3.6323499999998603,
#     'type_event': 0},
#    {'time_since_last_event': 0.09880100000009406,
#     'time_since_start': 3.7311509999999544,
#     'type_event': 3},
#    {'time_since_last_event': 0.2733189999999013,
#     'time_since_start': 4.004469999999856,
#     'type_event': 0},
#    {'time_since_last_event': 0.11232000000018161,
#     'time_since_start': 4.116790000000037,
#     'type_event': 0},
#    {'time_since_last_event': 0.17441300000064075,
#     'time_since_start': 4.291203000000678,
#     'type_event': 0},
#    {'time_since_last_event': 0.03833699999086093,
#     'time_since_start': 4.329539999991539,
#     'type_event': 1},
#    {'time_since_last_event': 1.0963940000074217,
#     'time_since_start': 5.425933999998961,
#     'type_event': 3},
#    {'time_since_last_event': 0.16322499999660067,
#     'time_since_start': 5.589158999995561,
#     'type_event': 1},
#    {'time_since_last_event': 0.8756649999995716,
#     'time_since_start': 6.464823999995133,
#     'type_event': 3},
#    {'time_since_last_event': 1.1762129999988247,
#     'time_since_start': 7.641036999993958,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.5683010000066133,
#     'time_since_start': 0.5683010000066133,
#     'type_event': 0},
#    {'time_since_last_event': 0.4831229999981588,
#     'time_since_start': 1.051424000004772,
#     'type_event': 0},
#    {'time_since_last_event': 1.5545850000053179,
#     'time_since_start': 2.60600900001009,
#     'type_event': 0},
#    {'time_since_last_event': 0.1958230000018375,
#     'time_since_start': 2.8018320000119274,
#     'type_event': 0},
#    {'time_since_last_event': 1.0653689999890048,
#     'time_since_start': 3.8672010000009323,
#     'type_event': 2},
#    {'time_since_last_event': 2.251738999999361,
#     'time_since_start': 6.118940000000293,
#     'type_event': 0},
#    {'time_since_last_event': 4.569872000007308,
#     'time_since_start': 10.688812000007601,
#     'type_event': 1},
#    {'time_since_last_event': 0.3007950000028359,
#     'time_since_start': 10.989607000010437,
#     'type_event': 2},
#    {'time_since_last_event': 0.5237169999891194,
#     'time_since_start': 11.513323999999557,
#     'type_event': 0},
#    {'time_since_last_event': 0.10217200001352467,
#     'time_since_start': 11.615496000013081,
#     'type_event': 1},
#    {'time_since_last_event': 0.43302799998491537,
#     'time_since_start': 12.048523999997997,
#     'type_event': 1},
#    {'time_since_last_event': 0.6959000000060769,
#     'time_since_start': 12.744424000004074,
#     'type_event': 2},
#    {'time_since_last_event': 6.235242000009748,
#     'time_since_start': 18.97966600001382,
#     'type_event': 2},
#    {'time_since_last_event': 1.1716509999969276,
#     'time_since_start': 20.15131700001075,
#     'type_event': 0},
#    {'time_since_last_event': 1.1947499999951106,
#     'time_since_start': 21.34606700000586,
#     'type_event': 0},
#    {'time_since_last_event': 2.4239850000012666,
#     'time_since_start': 23.770052000007126,
#     'type_event': 0},
#    {'time_since_last_event': 4.884680000002845,
#     'time_since_start': 28.65473200000997,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 1},
#    {'time_since_last_event': 0.4675120000028983,
#     'time_since_start': 0.4675120000028983,
#     'type_event': 4},
#    {'time_since_last_event': 0.015906999993603677,
#     'time_since_start': 0.48341899999650195,
#     'type_event': 3},
#    {'time_since_last_event': 1.7564100000017788,
#     'time_since_start': 2.239828999998281,
#     'type_event': 2},
#    {'time_since_last_event': 0.006397999997716397,
#     'time_since_start': 2.246226999995997,
#     'type_event': 3},
#    {'time_since_last_event': 0.7462300000042887,
#     'time_since_start': 2.992457000000286,
#     'type_event': 1},
#    {'time_since_last_event': 0.9289209999988088,
#     'time_since_start': 3.9213779999990948,
#     'type_event': 1},
#    {'time_since_last_event': 0.7927249999920605,
#     'time_since_start': 4.714102999991155,
#     'type_event': 1},
#    {'time_since_last_event': 0.1441259999992326,
#     'time_since_start': 4.858228999990388,
#     'type_event': 0},
#    {'time_since_last_event': 2.2558520000020508,
#     'time_since_start': 7.114080999992439,
#     'type_event': 2},
#    {'time_since_last_event': 0.21054200001526624,
#     'time_since_start': 7.324623000007705,
#     'type_event': 1},
#    {'time_since_last_event': 0.7695399999938672,
#     'time_since_start': 8.094163000001572,
#     'type_event': 2},
#    {'time_since_last_event': 0.06177899999602232,
#     'time_since_start': 8.155941999997594,
#     'type_event': 1},
#    {'time_since_last_event': 0.662769999995362,
#     'time_since_start': 8.818711999992956,
#     'type_event': 2},
#    {'time_since_last_event': 5.104033000010531,
#     'time_since_start': 13.922745000003488,
#     'type_event': 0},
#    {'time_since_last_event': 3.033087000003434,
#     'time_since_start': 16.95583200000692,
#     'type_event': 4},
#    {'time_since_last_event': 4.4089939999976195,
#     'time_since_start': 21.36482600000454,
#     'type_event': 0},
#    {'time_since_last_event': 2.6993879999936325,
#     'time_since_start': 24.064213999998174,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 2.1844600000040373,
#     'time_since_start': 2.1844600000040373,
#     'type_event': 0},
#    {'time_since_last_event': 0.13831799998297356,
#     'time_since_start': 2.322777999987011,
#     'type_event': 0},
#    {'time_since_last_event': 0.3785710000083782,
#     'time_since_start': 2.701348999995389,
#     'type_event': 2},
#    {'time_since_last_event': 0.6516200000041863,
#     'time_since_start': 3.3529689999995753,
#     'type_event': 0},
#    {'time_since_last_event': 4.126829999993788,
#     'time_since_start': 7.479798999993363,
#     'type_event': 1},
#    {'time_since_last_event': 1.6644580000138376,
#     'time_since_start': 9.144257000007201,
#     'type_event': 2},
#    {'time_since_last_event': 0.08226999998441897,
#     'time_since_start': 9.22652699999162,
#     'type_event': 0},
#    {'time_since_last_event': 1.8416609999985667,
#     'time_since_start': 11.068187999990187,
#     'type_event': 0},
#    {'time_since_last_event': 2.3619290000060573,
#     'time_since_start': 13.430116999996244,
#     'type_event': 0},
#    {'time_since_last_event': 4.4695449999999255,
#     'time_since_start': 17.89966199999617,
#     'type_event': 0},
#    {'time_since_last_event': 7.873036000004504,
#     'time_since_start': 25.772698000000673,
#     'type_event': 1},
#    {'time_since_last_event': 0.004923999993479811,
#     'time_since_start': 25.777621999994153,
#     'type_event': 2},
#    {'time_since_last_event': 0.012524000005214475,
#     'time_since_start': 25.790145999999368,
#     'type_event': 1},
#    {'time_since_last_event': 0.01031199999852106,
#     'time_since_start': 25.80045799999789,
#     'type_event': 0},
#    {'time_since_last_event': 0.8252839999913704,
#     'time_since_start': 26.62574199998926,
#     'type_event': 2},
#    {'time_since_last_event': 1.2087880000035511,
#     'time_since_start': 27.83452999999281,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 1},
#    {'time_since_last_event': 2.1487580000102753,
#     'time_since_start': 2.1487580000102753,
#     'type_event': 0},
#    {'time_since_last_event': 0.4470819999842206,
#     'time_since_start': 2.595839999994496,
#     'type_event': 2},
#    {'time_since_last_event': 0.5600760000088485,
#     'time_since_start': 3.1559160000033444,
#     'type_event': 1},
#    {'time_since_last_event': 0.6143790000060108,
#     'time_since_start': 3.770295000009355,
#     'type_event': 1},
#    {'time_since_last_event': 1.150975999989896,
#     'time_since_start': 4.921270999999251,
#     'type_event': 0},
#    {'time_since_last_event': 3.4035000000003492,
#     'time_since_start': 8.3247709999996,
#     'type_event': 0},
#    {'time_since_last_event': 1.114289999997709,
#     'time_since_start': 9.43906099999731,
#     'type_event': 1},
#    {'time_since_last_event': 0.000997000010102056,
#     'time_since_start': 9.440058000007411,
#     'type_event': 0},
#    {'time_since_last_event': 0.023300999993807636,
#     'time_since_start': 9.463359000001219,
#     'type_event': 0},
#    {'time_since_last_event': 2.3826649999973597,
#     'time_since_start': 11.846023999998579,
#     'type_event': 0},
#    {'time_since_last_event': 2.5724889999983134,
#     'time_since_start': 14.418512999996892,
#     'type_event': 1},
#    {'time_since_last_event': 0.11540900000545662,
#     'time_since_start': 14.533922000002349,
#     'type_event': 0},
#    {'time_since_last_event': 4.560652000000118,
#     'time_since_start': 19.094574000002467,
#     'type_event': 1},
#    {'time_since_last_event': 0.3951340000057826,
#     'time_since_start': 19.48970800000825,
#     'type_event': 2},
#    {'time_since_last_event': 1.4619179999863263,
#     'time_since_start': 20.951625999994576,
#     'type_event': 2}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 0.004814999992959201,
#     'time_since_start': 0.004814999992959201,
#     'type_event': 0},
#    {'time_since_last_event': 11.145757000005688,
#     'time_since_start': 11.150571999998647,
#     'type_event': 0},
#    {'time_since_last_event': 0.7835090000007767,
#     'time_since_start': 11.934080999999424,
#     'type_event': 5},
#    {'time_since_last_event': 0.0273449999949662,
#     'time_since_start': 11.96142599999439,
#     'type_event': 0},
#    {'time_since_last_event': 0.14244600001256913,
#     'time_since_start': 12.103872000006959,
#     'type_event': 0},
#    {'time_since_last_event': 0.8176259999891045,
#     'time_since_start': 12.921497999996063,
#     'type_event': 0},
#    {'time_since_last_event': 0.03665200000978075,
#     'time_since_start': 12.958150000005844,
#     'type_event': 0},
#    {'time_since_last_event': 0.21490199999243487,
#     'time_since_start': 13.173051999998279,
#     'type_event': 0},
#    {'time_since_last_event': 1.4848619999975199,
#     'time_since_start': 14.657913999995799,
#     'type_event': 1},
#    {'time_since_last_event': 0.04998900000646245,
#     'time_since_start': 14.707903000002261,
#     'type_event': 2},
#    {'time_since_last_event': 0.06292799999937415,
#     'time_since_start': 14.770831000001635,
#     'type_event': 1},
#    {'time_since_last_event': 0.18880400000489317,
#     'time_since_start': 14.959635000006529,
#     'type_event': 3},
#    {'time_since_last_event': 0.038451999993412755,
#     'time_since_start': 14.998086999999941,
#     'type_event': 0},
#    {'time_since_last_event': 0.8215519999939715,
#     'time_since_start': 15.819638999993913,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 0.9137670000054641,
#     'time_since_start': 0.9137670000054641,
#     'type_event': 0},
#    {'time_since_last_event': 0.8652039999869885,
#     'time_since_start': 1.7789709999924526,
#     'type_event': 0},
#    {'time_since_last_event': 1.0223990000085905,
#     'time_since_start': 2.801370000001043,
#     'type_event': 1},
#    {'time_since_last_event': 0.8701379999984056,
#     'time_since_start': 3.6715079999994487,
#     'type_event': 4},
#    {'time_since_last_event': 2.2927769999951124,
#     'time_since_start': 5.964284999994561,
#     'type_event': 3},
#    {'time_since_last_event': 0.08836900000460446,
#     'time_since_start': 6.0526539999991655,
#     'type_event': 0},
#    {'time_since_last_event': 1.1357169999973848,
#     'time_since_start': 7.18837099999655,
#     'type_event': 0},
#    {'time_since_last_event': 2.0991890000004787,
#     'time_since_start': 9.287559999997029,
#     'type_event': 1},
#    {'time_since_last_event': 0.5181530000118073,
#     'time_since_start': 9.805713000008836,
#     'type_event': 0},
#    {'time_since_last_event': 1.60049299999082,
#     'time_since_start': 11.406205999999656,
#     'type_event': 0},
#    {'time_since_last_event': 0.24666499999875668,
#     'time_since_start': 11.652870999998413,
#     'type_event': 0},
#    {'time_since_last_event': 2.6423979999963194,
#     'time_since_start': 14.295268999994732,
#     'type_event': 1},
#    {'time_since_last_event': 3.216221000009682,
#     'time_since_start': 17.511490000004414,
#     'type_event': 0},
#    {'time_since_last_event': 0.4080659999890486,
#     'time_since_start': 17.919555999993463,
#     'type_event': 1},
#    {'time_since_last_event': 0.03985100000863895,
#     'time_since_start': 17.959407000002102,
#     'type_event': 1},
#    {'time_since_last_event': 1.6375600000028498,
#     'time_since_start': 19.596967000004952,
#     'type_event': 2},
#    {'time_since_last_event': 0.6606319999991683,
#     'time_since_start': 20.25759900000412,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 0.0022489999973913655,
#     'time_since_start': 0.0022489999973913655,
#     'type_event': 0},
#    {'time_since_last_event': 0.6874390000011772,
#     'time_since_start': 0.6896879999985686,
# ...
#     'time_since_start': 0.567512000023271,
#     'type_event': 2},
#    {'time_since_last_event': 0.0716919999831589,
#     'time_since_start': 0.6392040000064299,
#     'type_event': 1},
#    {'time_since_last_event': 0.07330499999807216,
#     'time_since_start': 0.712509000004502,
#     'type_event': 2},
#    {'time_since_last_event': 0.027092000003904104,
#     'time_since_start': 0.7396010000084061,
#     'type_event': 0},
#    {'time_since_last_event': 0.03925699999672361,
#     'time_since_start': 0.7788580000051297,
#     'type_event': 3}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.03039899999566842,
#     'time_since_start': 0.03039899999566842,
#     'type_event': 2},
#    {'time_since_last_event': 0.10861999999906402,
#     'time_since_start': 0.13901899999473244,
#     'type_event': 2},
#    {'time_since_last_event': 0.022710000004735775,
#     'time_since_start': 0.16172899999946821,
#     'type_event': 2},
#    {'time_since_last_event': 0.024793000004137866,
#     'time_since_start': 0.18652200000360608,
#     'type_event': 2},
#    {'time_since_last_event': 0.13627000000269618,
#     'time_since_start': 0.32279200000630226,
#     'type_event': 2},
#    {'time_since_last_event': 0.09861999997519888,
#     'time_since_start': 0.42141199998150114,
#     'type_event': 2},
#    {'time_since_last_event': 0.03465700002561789,
#     'time_since_start': 0.45606900000711903,
#     'type_event': 1},
#    {'time_since_last_event': 0.012786999985110015,
#     'time_since_start': 0.46885599999222904,
#     'type_event': 2},
#    {'time_since_last_event': 0.05013199998938944,
#     'time_since_start': 0.5189879999816185,
#     'type_event': 2},
#    {'time_since_last_event': 0.05020200002763886,
#     'time_since_start': 0.5691900000092573,
#     'type_event': 1},
#    {'time_since_last_event': 0.04526199998508673,
#     'time_since_start': 0.6144519999943441,
#     'type_event': 1},
#    {'time_since_last_event': 0.06080899998778477,
#     'time_since_start': 0.6752609999821289,
#     'type_event': 2},
#    {'time_since_last_event': 0.041936000023270026,
#     'time_since_start': 0.7171970000053989,
#     'type_event': 2},
#    {'time_since_last_event': 0.18004500000097323,
#     'time_since_start': 0.8972420000063721,
#     'type_event': 2},
#    {'time_since_last_event': 0.05148799998278264,
#     'time_since_start': 0.9487299999891547,
#     'type_event': 1},
#    {'time_since_last_event': 0.04323500001919456,
#     'time_since_start': 0.9919650000083493,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.02139500000339467,
#     'time_since_start': 0.02139500000339467,
#     'type_event': 2},
#    {'time_since_last_event': 0.08378700002504047,
#     'time_since_start': 0.10518200002843514,
#     'type_event': 2},
#    {'time_since_last_event': 0.045164999974076636,
#     'time_since_start': 0.15034700000251178,
#     'type_event': 2},
#    {'time_since_last_event': 0.02531100001942832,
#     'time_since_start': 0.1756580000219401,
#     'type_event': 0},
#    {'time_since_last_event': 0.03591599997889716,
#     'time_since_start': 0.21157400000083726,
#     'type_event': 0},
#    {'time_since_last_event': 0.031993000011425465,
#     'time_since_start': 0.24356700001226272,
#     'type_event': 1},
#    {'time_since_last_event': 0.06741400000464637,
#     'time_since_start': 0.3109810000169091,
#     'type_event': 2},
#    {'time_since_last_event': 0.06510599999455735,
#     'time_since_start': 0.37608700001146644,
#     'type_event': 0},
#    {'time_since_last_event': 0.02398399999947287,
#     'time_since_start': 0.4000710000109393,
#     'type_event': 2},
#    {'time_since_last_event': 0.055644000007305294,
#     'time_since_start': 0.4557150000182446,
#     'type_event': 0},
#    {'time_since_last_event': 0.028976000001421198,
#     'time_since_start': 0.4846910000196658,
#     'type_event': 0},
#    {'time_since_last_event': 0.034385999984806404,
#     'time_since_start': 0.5190770000044722,
#     'type_event': 1},
#    {'time_since_last_event': 0.0456300000223564,
#     'time_since_start': 0.5647070000268286,
#     'type_event': 0},
#    {'time_since_last_event': 0.05247699999017641,
#     'time_since_start': 0.617184000017005,
#     'type_event': 1},
#    {'time_since_last_event': 0.19570399999793153,
#     'time_since_start': 0.8128880000149366,
#     'type_event': 0}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.04832000000169501,
#     'time_since_start': 0.04832000000169501,
#     'type_event': 2},
#    {'time_since_last_event': 0.19686399998317938,
#     'time_since_start': 0.2451839999848744,
#     'type_event': 1},
#    {'time_since_last_event': 0.27903400002105627,
#     'time_since_start': 0.5242180000059307,
#     'type_event': 1},
#    {'time_since_last_event': 0.02460399999108631,
#     'time_since_start': 0.548821999997017,
#     'type_event': 2},
#    {'time_since_last_event': 0.051255999991553836,
#     'time_since_start': 0.6000779999885708,
#     'type_event': 2},
#    {'time_since_last_event': 0.051322000013897195,
#     'time_since_start': 0.651400000002468,
#     'type_event': 0},
#    {'time_since_last_event': 0.02923900001042057,
#     'time_since_start': 0.6806390000128886,
#     'type_event': 2},
#    {'time_since_last_event': 0.1648739999945974,
#     'time_since_start': 0.845513000007486,
#     'type_event': 1},
#    {'time_since_last_event': 0.047689999992144294,
#     'time_since_start': 0.8932029999996303,
#     'type_event': 2},
#    {'time_since_last_event': 0.02895699998771306,
#     'time_since_start': 0.9221599999873433,
#     'type_event': 1},
#    {'time_since_last_event': 0.028932000015629455,
#     'time_since_start': 0.9510920000029728,
#     'type_event': 1},
#    {'time_since_last_event': 0.018481999999494292,
#     'time_since_start': 0.9695740000024671,
#     'type_event': 0},
#    {'time_since_last_event': 0.05304499999328982,
#     'time_since_start': 1.022618999995757,
#     'type_event': 1},
#    {'time_since_last_event': 0.05494300001009833,
#     'time_since_start': 1.0775620000058552,
#     'type_event': 2},
#    {'time_since_last_event': 0.026211999997030944,
#     'time_since_start': 1.1037740000028862,
#     'type_event': 0},
#    {'time_since_last_event': 0.019248999989940785,
#     'time_since_start': 1.123022999992827,
#     'type_event': 1},
#    {'time_since_last_event': 0.02560200000880286,
#     'time_since_start': 1.1486250000016298,
#     'type_event': 1}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.04609199998958502,
#     'time_since_start': 0.04609199998958502,
#     'type_event': 2},
#    {'time_since_last_event': 0.028286000015214086,
#     'time_since_start': 0.0743780000047991,
#     'type_event': 1},
#    {'time_since_last_event': 0.03189899999415502,
#     'time_since_start': 0.10627699999895412,
#     'type_event': 2},
#    {'time_since_last_event': 0.012643999987631105,
#     'time_since_start': 0.11892099998658523,
#     'type_event': 5},
#    {'time_since_last_event': 0.011508000010508113,
#     'time_since_start': 0.13042899999709334,
#     'type_event': 2},
#    {'time_since_last_event': 0.00764799999888055,
#     'time_since_start': 0.1380769999959739,
#     'type_event': 0},
#    {'time_since_last_event': 0.04383399999642279,
#     'time_since_start': 0.18191099999239668,
#     'type_event': 0},
#    {'time_since_last_event': 0.028861999991931953,
#     'time_since_start': 0.21077299998432864,
#     'type_event': 1},
#    {'time_since_last_event': 0.05440500001714099,
#     'time_since_start': 0.2651780000014696,
#     'type_event': 0},
#    {'time_since_last_event': 0.19732799999474082,
#     'time_since_start': 0.46250599999621045,
#     'type_event': 2},
#    {'time_since_last_event': 0.05588799998804461,
#     'time_since_start': 0.5183939999842551,
#     'type_event': 2},
#    {'time_since_last_event': 0.023863000009441748,
#     'time_since_start': 0.5422569999936968,
#     'type_event': 2},
#    {'time_since_last_event': 0.02434099998208694,
#     'time_since_start': 0.5665979999757838,
#     'type_event': 1},
#    {'time_since_last_event': 0.059314000012818724,
#     'time_since_start': 0.6259119999886025,
#     'type_event': 2},
#    {'time_since_last_event': 0.057013000012375414,
#     'time_since_start': 0.6829250000009779,
#     'type_event': 2}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 0.1216300000087358,
#     'time_since_start': 0.1216300000087358,
#     'type_event': 2},
#    {'time_since_last_event': 0.13774399999238085,
#     'time_since_start': 0.25937400000111666,
#     'type_event': 2},
#    {'time_since_last_event': 0.04166800000530202,
#     'time_since_start': 0.3010420000064187,
#     'type_event': 2},
#    {'time_since_last_event': 0.05305499999667518,
#     'time_since_start': 0.35409700000309385,
#     'type_event': 0},
#    {'time_since_last_event': 0.06988900000578724,
#     'time_since_start': 0.4239860000088811,
#     'type_event': 2},
#    {'time_since_last_event': 0.06316900000092573,
#     'time_since_start': 0.4871550000098068,
#     'type_event': 1},
#    {'time_since_last_event': 0.021344999986467883,
#     'time_since_start': 0.5084999999962747,
#     'type_event': 2},
#    {'time_since_last_event': 0.06288200001290534,
#     'time_since_start': 0.57138200000918,
#     'type_event': 2},
#    {'time_since_last_event': 0.03815999999642372,
#     'time_since_start': 0.6095420000056038,
#     'type_event': 2},
#    {'time_since_last_event': 0.036489000005531125,
#     'time_since_start': 0.6460310000111349,
#     'type_event': 2},
#    {'time_since_last_event': 0.05488199999672361,
#     'time_since_start': 0.7009130000078585,
#     'type_event': 2},
#    {'time_since_last_event': 0.02104700000199955,
#     'time_since_start': 0.721960000009858,
#     'type_event': 1},
#    {'time_since_last_event': 0.10825599999225233,
#     'time_since_start': 0.8302160000021104,
#     'type_event': 1},
#    {'time_since_last_event': 0.022679999994579703,
#     'time_since_start': 0.8528959999966901,
#     'type_event': 2},
#    {'time_since_last_event': 0.14882699999725446,
#     'time_since_start': 1.0017229999939445,
#     'type_event': 2}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 0},
#    {'time_since_last_event': 0.06830600001558196,
#     'time_since_start': 0.06830600001558196,
#     'type_event': 2},
#    {'time_since_last_event': 0.01607400001375936,
#     'time_since_start': 0.08438000002934132,
#     'type_event': 0},
#    {'time_since_last_event': 0.014194999981555156,
#     'time_since_start': 0.09857500001089647,
#     'type_event': 0},
#    {'time_since_last_event': 0.00025099999038502574,
#     'time_since_start': 0.0988260000012815,
#     'type_event': 1},
#    {'time_since_last_event': 0.20421300001908094,
#     'time_since_start': 0.30303900002036244,
#     'type_event': 0},
#    {'time_since_last_event': 0.03239200000825804,
#     'time_since_start': 0.3354310000286205,
#     'type_event': 2},
#    {'time_since_last_event': 0.049461999980849214,
#     'time_since_start': 0.3848930000094697,
#     'type_event': 2},
#    {'time_since_last_event': 0.04225600000063423,
#     'time_since_start': 0.4271490000101039,
#     'type_event': 2},
#    {'time_since_last_event': 0.06307200000446755,
#     'time_since_start': 0.4902210000145715,
#     'type_event': 0},
#    {'time_since_last_event': 0.04298700000799727,
#     'time_since_start': 0.5332080000225687,
#     'type_event': 1},
#    {'time_since_last_event': 0.025211999993189238,
#     'time_since_start': 0.558420000015758,
#     'type_event': 1},
#    {'time_since_last_event': 0.04094200000690762,
#     'time_since_start': 0.5993620000226656,
#     'type_event': 1},
#    {'time_since_last_event': 0.10480199998710304,
#     'time_since_start': 0.7041640000097686,
#     'type_event': 2},
#    {'time_since_last_event': 0.03719100001035258,
#     'time_since_start': 0.7413550000201212,
#     'type_event': 2},
#    {'time_since_last_event': 0.045400999995763414,
#     'time_since_start': 0.7867560000158846,
#     'type_event': 2},
#    {'time_since_last_event': 0.19914099999004975,
#     'time_since_start': 0.9858970000059344,
#     'type_event': 0},
#    {'time_since_last_event': 0.06760100000246894,
#     'time_since_start': 1.0534980000084033,
#     'type_event': 2}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.0173380000051111,
#     'time_since_start': 0.0173380000051111,
#     'type_event': 2},
#    {'time_since_last_event': 0.021488999991561286,
#     'time_since_start': 0.038826999996672384,
#     'type_event': 1},
#    {'time_since_last_event': 0.013445000004139729,
#     'time_since_start': 0.05227200000081211,
#     'type_event': 1},
#    {'time_since_last_event': 0.033617000008234754,
#     'time_since_start': 0.08588900000904687,
#     'type_event': 2},
#    {'time_since_last_event': 0.09366199998476077,
#     'time_since_start': 0.17955099999380764,
#     'type_event': 2},
#    {'time_since_last_event': 0.02496000002429355,
#     'time_since_start': 0.20451100001810119,
#     'type_event': 1},
#    {'time_since_last_event': 0.02848099998664111,
#     'time_since_start': 0.2329920000047423,
#     'type_event': 2},
#    {'time_since_last_event': 0.028490000011515804,
#     'time_since_start': 0.2614820000162581,
#     'type_event': 2},
#    {'time_since_last_event': 0.027867999975569546,
#     'time_since_start': 0.28934999999182764,
#     'type_event': 1},
#    {'time_since_last_event': 0.2447070000198437,
#     'time_since_start': 0.5340570000116713,
#     'type_event': 2},
#    {'time_since_last_event': 0.03244599998288322,
#     'time_since_start': 0.5665029999945546,
#     'type_event': 2},
#    {'time_since_last_event': 0.08033800001430791,
#     'time_since_start': 0.6468410000088625,
#     'type_event': 1},
#    {'time_since_last_event': 0.03490899999451358,
#     'time_since_start': 0.681750000003376,
#     'type_event': 2},
#    {'time_since_last_event': 0.0530739999958314,
#     'time_since_start': 0.7348239999992074,
#     'type_event': 2},
#    {'time_since_last_event': 0.03000600000086706,
#     'time_since_start': 0.7648300000000745,
#     'type_event': 2},
#    {'time_since_last_event': 0.0378400000045076,
#     'time_since_start': 0.8026700000045821,
#     'type_event': 2}],
#   [{'time_since_last_event': 0.0, 'time_since_start': 0.0, 'type_event': 2},
#    {'time_since_last_event': 0.054157999984454364,
#     'time_since_start': 0.054157999984454364,
#     'type_event': 0},
#    {'time_since_last_event': 0.09415999999328051,
#     'time_since_start': 0.14831799997773487,
#     'type_event': 2},
#    {'time_since_last_event': 0.04373300001316238,
#     'time_since_start': 0.19205099999089725,
#     'type_event': 1},
#    {'time_since_last_event': 0.0512190000154078,
#     'time_since_start': 0.24327000000630505,
#     'type_event': 2},
#    {'time_since_last_event': 0.03981399998883717,
#     'time_since_start': 0.2830839999951422,
#     'type_event': 1},
#    {'time_since_last_event': 0.03484399999433663,
#     'time_since_start': 0.31792799998947885,
#     'type_event': 3},
#    {'time_since_last_event': 0.037892000007559545,
#     'time_since_start': 0.3558199999970384,
#     'type_event': 3},
#    {'time_since_last_event': 0.06740100000752136,
#     'time_since_start': 0.42322100000455976,
#     'type_event': 3},
#    {'time_since_last_event': 0.13829109999642242,
#     'time_since_start': 0.5615121000009822,
#     'type_event': 0},
#    {'time_since_last_event': 0.008858900007908233,
#     'time_since_start': 0.5703710000088904,
#     'type_event': 2},
#    {'time_since_last_event': 0.034009999988484196,
#     'time_since_start': 0.6043809999973746,
#     'type_event': 3},
#    {'time_since_last_event': 0.053910999980871566,
#     'time_since_start': 0.6582919999782462,
#     'type_event': 2},
#    {'time_since_last_event': 0.1026020000281278,
#     'time_since_start': 0.760894000006374,
#     'type_event': 2},
#    {'time_since_last_event': 0.05553699999290984,
#     'time_since_start': 0.8164309999992838,
#     'type_event': 2},
#    {'time_since_last_event': 0.024825999993481673,
#     'time_since_start': 0.8412569999927655,
#     'type_event': 1},
#    {'time_since_last_event': 0.08940399999846704,
#     'time_since_start': 0.9306609999912325,
#     'type_event': 1}],
#   ...]}

# %%
# get dimension, the number of event types
dim_process = train_dict['dim_process']

# get the training data by subsetting the dictionary
train_data = train_dict['train']

# convert the training data to the format that the tokenizer expects (convert dictionary of dictionaries to list of lists)
time_seqs = [[x["time_since_start"] for x in seq] for seq in train_data]
type_seqs = [[x["type_event"] for x in seq] for seq in train_data]
time_delta_seqs = [[x["time_since_last_event"] for x in seq] for seq in train_data]

input_data = {'time_seqs': time_seqs,
                'type_seqs': type_seqs,
                'time_delta_seqs': time_delta_seqs}

config = DataSpecConfig.parse_from_yaml_config({'num_event_types': dim_process,  'pad_token_id': dim_process})

tokenizer = EventTokenizer(config)

# return_tensors='pt' will return the output as PyTorch tensors
output = tokenizer.pad(input_data, return_tensors='pt')

print(output)
# Out:
# {'time_seqs': tensor([[0.0000e+00, 1.2051e+00, 1.2390e+00,  ..., 1.9818e+01, 1.9842e+01,
#          7.0000e+00],
#         [0.0000e+00, 5.6208e+00, 5.7464e+00,  ..., 2.2073e+01, 2.3913e+01,
#          7.0000e+00],
#         [0.0000e+00, 1.3862e-01, 9.6840e+00,  ..., 5.2158e+01, 5.2163e+01,
#          7.0000e+00],
#         ...,
#         [0.0000e+00, 8.2689e-01, 2.0075e+00,  ..., 1.4963e+01, 1.5105e+01,
#          7.0000e+00],
#         [0.0000e+00, 4.0136e-02, 2.0609e-01,  ..., 7.1222e-01, 7.8175e-01,
#          9.1837e-01],
#         [0.0000e+00, 1.0268e-01, 5.8591e-01,  ..., 7.0000e+00, 7.0000e+00,
#          7.0000e+00]]), 'time_delta_seqs': tensor([[0.0000e+00, 1.2051e+00, 3.3874e-02,  ..., 3.1534e-01, 2.4082e-02,
#          7.0000e+00],
#         [0.0000e+00, 5.6208e+00, 1.2562e-01,  ..., 6.4807e-01, 1.8403e+00,
#          7.0000e+00],
#         [0.0000e+00, 1.3862e-01, 9.5454e+00,  ..., 1.6073e+00, 5.4100e-03,
#          7.0000e+00],
#         ...,
#         [0.0000e+00, 8.2689e-01, 1.1806e+00,  ..., 2.6363e-01, 1.4202e-01,
#          7.0000e+00],
#         [0.0000e+00, 4.0136e-02, 1.6596e-01,  ..., 4.1560e-02, 6.9539e-02,
#          1.3661e-01],
#         [0.0000e+00, 1.0268e-01, 4.8323e-01,  ..., 7.0000e+00, 7.0000e+00,
#          7.0000e+00]]), 'type_seqs': tensor([[0, 0, 1,  ..., 0, 6, 7],
#         [0, 0, 3,  ..., 0, 0, 7],
#         [0, 1, 3,  ..., 3, 0, 7],
#         ...,
#         [2, 1, 0,  ..., 0, 0, 7],
#         [0, 0, 2,  ..., 0, 3, 1],
#         [0, 0, 2,  ..., 7, 7, 7]]), 'seq_non_pad_mask': tensor([[ True,  True,  True,  ...,  True,  True, False],
#         [ True,  True,  True,  ...,  True,  True, False],
#         [ True,  True,  True,  ...,  True,  True, False],
#         ...,
#         [ True,  True,  True,  ...,  True,  True, False],
#         [ True,  True,  True,  ...,  True,  True,  True],
#         [ True,  True,  True,  ..., False, False, False]]), 'attention_mask': tensor([[[False,  True,  True,  ...,  True,  True,  True],
#          [False, False,  True,  ...,  True,  True,  True],
#          [False, False, False,  ...,  True,  True,  True],
#          ...,
#          [False, False, False,  ..., False,  True,  True],
#          [False, False, False,  ..., False, False,  True],
#          [False, False, False,  ..., False, False,  True]],
#
#         [[False,  True,  True,  ...,  True,  True,  True],
#          [False, False,  True,  ...,  True,  True,  True],
#          [False, False, False,  ...,  True,  True,  True],
#          ...,
#          [False, False, False,  ..., False,  True,  True],
#          [False, False, False,  ..., False, False,  True],
#          [False, False, False,  ..., False, False,  True]],
#
#         [[False,  True,  True,  ...,  True,  True,  True],
#          [False, False,  True,  ...,  True,  True,  True],
#          [False, False, False,  ...,  True,  True,  True],
#          ...,
#          [False, False, False,  ..., False,  True,  True],
#          [False, False, False,  ..., False, False,  True],
#          [False, False, False,  ..., False, False,  True]],
#
#         ...,
#
#         [[False,  True,  True,  ...,  True,  True,  True],
#          [False, False,  True,  ...,  True,  True,  True],
#          [False, False, False,  ...,  True,  True,  True],
#          ...,
#          [False, False, False,  ..., False,  True,  True],
#          [False, False, False,  ..., False, False,  True],
#          [False, False, False,  ..., False, False,  True]],
#
#         [[False,  True,  True,  ...,  True,  True,  True],
#          [False, False,  True,  ...,  True,  True,  True],
#          [False, False, False,  ...,  True,  True,  True],
#          ...,
#          [False, False, False,  ..., False,  True,  True],
#          [False, False, False,  ..., False, False,  True],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False,  True,  True,  ...,  True,  True,  True],
#          [False, False,  True,  ...,  True,  True,  True],
#          [False, False, False,  ...,  True,  True,  True],
#          ...,
#          [False, False, False,  ...,  True,  True,  True],
#          [False, False, False,  ...,  True,  True,  True],
#          [False, False, False,  ...,  True,  True,  True]]])}

# %%
from models.encoders.gru import GRUTPPEncoder
from models.decoders.rmtpp import RMTPPDecoder, RMTPPLoss

# Data Processing Pipeline
def prepare_data(raw_data, config):
    """Prepare data with right padding
    
    Args:
        raw_data: dictionary of dictionaries
        config: DataSpecConfig object
    """
    # Initialize tokenizer with right padding
    tokenizer = EventTokenizer(config)
    tokenizer.padding_side = 'right'  # Ensure right padding
    
    # Prepare input format for tokenizer
    input_data = {
        'time_seqs': [[x["time_since_start"] for x in seq] for seq in raw_data],
        'type_seqs': [[x["type_event"] for x in seq] for seq in raw_data],
        'time_delta_seqs': [[x["time_since_last_event"] for x in seq] for seq in raw_data]
    }
    
    # Get sequence lengths before padding
    sequence_length = torch.tensor([len(seq) for seq in input_data['type_seqs']])
    
    # Process with tokenizer, return as PyTorch tensors, do not return attention masks
    batch = tokenizer.pad(input_data, return_tensors='pt', return_attention_mask=False)
    batch['sequence_length'] = sequence_length
    
    return batch


dim_process = train_dict['dim_process']
train_data = train_dict['train']

config = DataSpecConfig.parse_from_yaml_config({
    'num_event_types': dim_process,
    'pad_token_id': dim_process
})

HIDDEN_DIM = 128


# Process data once
processed_data = prepare_data(train_data, config)

# Create model
encoder = GRUTPPEncoder(config, hidden_dim=HIDDEN_DIM)

# Train/inference with processed data
output = encoder(processed_data)

# %%
processed_data["sequence_length"]
# Out:
# tensor([17, 17, 17,  ..., 17, 18, 15])

# %%
MLP_DIM = 64
device = 'cpu' if not torch.cuda.is_available() else 'cuda'


# decode
decoder = RMTPPDecoder(hidden_dim=HIDDEN_DIM, num_event_types=dim_process, mlp_dim=MLP_DIM, device='cpu')
decoder_output = decoder(output)

criterion = RMTPPLoss(device=device, ignore_index=config.pad_token_id)

# Forward pass
hidden_states = encoder(processed_data)
decoder_output = decoder(hidden_states)

# Compute loss
time_loss, mark_loss, total_loss = criterion.forward(
    decoder_output,
    processed_data["time_delta_seqs"], 
    processed_data["type_seqs"],
    processed_data["sequence_length"]
)
